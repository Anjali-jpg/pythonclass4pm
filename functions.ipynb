# %%
#-Pre-defined
print()
int()
float()
list()
dict()
tuple()

# %%
#user-defined

# %%
def hello():
    print("hello world")
hello()
# Out:
# hello world

# %%
def hello(x):                #with parameters
    print(x)
hello("hello world")
# Out:
# hello world

# %%
def calc():                               #calculation pblm
    l=int(input("enter l="))
    b=int(input("enter b="))
    h=int(input("enter h="))
    v=l*b*h
    print(v)
calc()
# Out:
# enter l=1
# enter b=2
# enter h=3
# 6

# %%
def calc():                               #calculation pblm
    l=int(input("enter l="))
    b=int(input("enter b="))
    h=int(input("enter h="))
    v=l*b*h
    print(v) 
for i in range(5):
        calc()
# Out:
# enter l=2
# enter b=3
# enter h=4
# 24
# enter l=5
# enter b=5
# enter h=6
# 150
# enter l=6
# enter b=6
# enter h=6
# 216
# enter l=1
# enter b=1
# enter h=1
# 1
# enter l=1
# enter b=2
# enter h=3
# 6

# %%
def calc():                               #calculation pblm by local variables
    l=int(input("enter l="))
    b=int(input("enter b="))             #local variables are the one that is calculated inside function
    h=int(input("enter h="))
    v=l*b*h
    print(v) 
calc()
# Out:
# enter l=3
# enter b=3
# enter h=3
# 27

# %%
def calc():                               #calculation pblm by global variables
   
    v=l*b*h
    print(v)
l=int(input("enter l="))
b=int(input("enter b="))             #global variables are the one that is calculated outside function
h=int(input("enter h="))
calc()
# Out:
# enter l=2
# enter b=2
# enter h=2
# 8

# %%
l=int(input("enter l="))
b=int(input("enter b="))             #global variables are the one that is calculated outside function
h=int(input("enter h="))

def calc():                               #calculation pblm by global variables
   
    v=l*b*h
    print(v)

calc()
# Out:
# enter l=2
# enter b=2
# enter h=2
# 8

# %%
#arguments
#return

# %%
def calc(x,y,z):                    #parameters                         
   
    v=x*y*z
    print(v)
    
l=int(input("enter l="))
b=int(input("enter b="))        
h=int(input("enter h="))

calc(l,b,h)                         #arguments
# Out:
# enter l=3
# enter b=2
# enter h=1
# 6

# %%
def hello(x):
    print(x)
    
hello("Namaste")
# Out:
# Namaste

# %%
def calc(k):
    x,y,z=k                         
   
    v=x*y*z
    print(v)
    
l=int(input("enter l="))
b=int(input("enter b="))        
h=int(input("enter h="))

k=[l,b,h]
calc(k)
# Out:
# enter l=2
# enter b=3
# enter h=4
# 24

# %%
def calc(k):
    x,y,z=k                         
   
    v=x*y*z
    print(v)
    
l=int(input("enter l="))
b=int(input("enter b="))        
h=int(input("enter h="))

k={l,b,h}
calc(k)
# Out:
# enter l=4
# enter b=3
# enter h=2
# 24

# %%
def language(lan="Python"):                  
    print(lan)
    
language("c")
language("c++")
language("java")
language()
# Out:
# c
# c++
# java
# Python

# %%
#return

# %%
def calc(x,y,z):                                             
   
    v=x*y*z
    return v
   
    
l=int(input("enter l="))
b=int(input("enter b="))        
h=int(input("enter h="))

print(calc(l,b,h))
# Out:
# enter l=3
# enter b=2
# enter h=3
# 18

# %%
def calc(x,y,z):                                             
   
    v=x*y*z
    return v
   
    
l=int(input("enter l="))
b=int(input("enter b="))        
h=int(input("enter h="))

calc(l,b,h)
# Out:
# enter l=3
# enter b=4
# enter h=4
# 48

# %%
def cal(x,y):
    a=x*y
    return a

l=int(input("enter l="))
b=int(input("enter b="))        
h=int(input("enter h="))

ar=cal(l,b)

volume=ar*h

print(volume)
print(ar)
# Out:
# enter l=3
# enter b=4
# enter h=3
# 36
# 12

# %%
def hello():
    x="namaste"
    print(x)
    
hello()
print(x)
# Out:
# namaste
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-22f459281f79> in <module>
#       4
#       5 hello()
# ----> 6 print(x)
#
# NameError: name 'x' is not defined

# %%
def hello():                      #local variables to global
    global x
    x="namaste"
    print(x)
    
hello()
print(x)
# Out:
# namaste
# namaste

# %%
def area(x,y):                           #function inside function
    a=x*y
    return a

def volume(x,y,z):
    v=area(x,y)*h
    return v

l=int(input("enter l="))
b=int(input("enter b="))        
h=int(input("enter h="))

vol=volume(l,b,h)
print(vol)

ar=area(l,b)
print(ar)
# Out:
# enter l=4
# enter b=5
# enter h=3
# 60
# 20

# %%
#math
#recursive

# %%
import math as m
m.factorial(4)
# Out:
# 24

# %%
m.log(5)
# Out:
# 1.6094379124341003

# %%
m.sin(90)                  #value should be 1
# Out:
# 0.8939966636005579

# %%
a=m.pi/2                       #value can be assigned
m.sin(a)
# Out:
# 1.0

# %%
m.acos(1)
# Out:
# 0.0

# %%
m.acos(0)
# Out:
# 1.5707963267948966

# %%
#Recursive function

# %%
def hello():                #inside function if another function is called, it's recursive
    print("hello world")
    hello()
    
hello()
# Out:
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# ...

# %% [markdown]
# def hello():                                #recursive is used rare but in this we control recursive
#     x=int(input("enter x="))
#     if x==0:
#         print("hello world")
#         hello()
#
# hello()

# %%
def hello():                  #recursive is used rare but in this we control recursive
    x=int(input("enter x="))
    if x==0:
        print("hello world") 
        hello()

hello()
# Out:
# enter x=0
# hello world
# enter x=0
# hello world
# enter x=10

# %%
def my_function(*kids):                         #(*)-if we dont know number of arguments to be passed in function
    print("The youngest child is " + kids[2])

# %%
def my_function(**kid):                         #(**)-if we dont know hom much keyword arguments will be passes in function
    print("His last name is " + kid["lname"])
